# %% [markdown]
# # GMM (GaussianMixture Model)
#
# 做自訂義data的簡易分群

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.mixture import GaussianMixture

# 生成數據
X, y_true = make_blobs(n_samples=300, centers=6, cluster_std=0.60, random_state=0)

# 可視化原始數據
plt.scatter(X[:, 0], X[:, 1], s=40, cmap='viridis')
plt.title("Original Data")
plt.show()

# 建立GaussianMixture模型
gmm = GaussianMixture(n_components=6)
gmm.fit(X)

# 預測數據的分類
labels = gmm.predict(X)

# 可視化聚類結果
plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis')
plt.title("GMM Clustering Result")
plt.show()

# 打印高斯混合模型的均值和方差
print("Means:\n", gmm.means_)
print("Covariances:\n", gmm.covariances_)
# Out:
# <ipython-input-4-57b557a3320e>:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], s=40, cmap='viridis')
# Means:
#  [[ 5.62826135  0.43961866]
#  [ 0.94175066  4.352294  ]
#  [-1.37472184  7.70985065]
#  [ 9.30538058 -2.35144311]
#  [ 2.04035807  0.94828722]
#  [-1.6417518   2.92346356]]
# Covariances:
#  [[[ 0.34271575  0.00365314]
#   [ 0.00365314  0.3770633 ]]
#
#  [[ 0.43181904 -0.01234353]
#   [-0.01234353  0.372949  ]]
#
#  [[ 0.33742327 -0.00555027]
#   [-0.00555027  0.27186677]]
#
#  [[ 0.41341404  0.06398973]
#   [ 0.06398973  0.38213494]]
#
#  [[ 0.28883162  0.00291428]
#   [ 0.00291428  0.35799905]]
#
#  [[ 0.33931125 -0.06051741]
#   [-0.06051741  0.32928312]]]

# %% [markdown]
# # SVM (Support Vector Machine)

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# 載入鳶尾花數據集
iris = datasets.load_iris()
X = iris.data
y = iris.target

# 分割數據集為訓練集和測試集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 特徵縮放
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 建立SVM模型
clf = SVC(kernel='linear', C=1.0, random_state=42)

# 訓練模型
clf.fit(X_train, y_train)

# 預測
y_pred = clf.predict(X_test)

# 評估模型
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.98

# %% [markdown]
# # 作業
# - 參加kaggle的競賽:[Titanic](https://www.kaggle.com/competitions/titanic/overview)
# - 可以參考下列
#   - [網站鐵達尼號生存預測](https://yulongtsai.medium.com/https-medium-com-yulongtsai-titanic-top3-8e64741cc11f)
#   - [鐵達尼號英文教學(有用SVM)](https://www.youtube.com/watch?v=I3FBJdiExcg)
#   - [別人做的範例](https://colab.research.google.com/#fileId=https%3A//storage.googleapis.com/kaggle-colab-exported-notebooks/titanic-survival-prediction-using-svm-259717e3-3f52-4ca9-ade7-83f97dd71634.ipynb%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com/20240728/auto/storage/goog4_request%26X-Goog-Date%3D20240728T145454Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...)
#
#
#
# ![image.png](data:image/png;base64,...)
